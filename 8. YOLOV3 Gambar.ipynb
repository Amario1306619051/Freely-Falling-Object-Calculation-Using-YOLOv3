# %%
import cv2 
import numpy as np
import time

# %%
net = cv2.dnn.readNet('/Users/amariofausta/Downloads/yolov3custom_last.weights','/Users/amariofausta/Downloads/yolov3custom (1).cfg')

# %%
import cv2 
import numpy as np
net = cv2.dnn.readNet('/Users/amariofausta/Documents/Kuliah/Semester 8/Bobot/yolov3-tiny_final.weights','/Users/amariofausta/Documents/Kuliah/Semester 8/Bobot/yolov3-tiny.cfg')
classes = []
with open("/Users/amariofausta/Documents/Kuliah/Semester 8/Code/Dataset/Dataset Custom/classes.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]

# %%
classes = []
with open("/Users/amariofausta/Documents/Kuliah/Semester 8/Code/Dataset/Dataset Custom/classes.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
classes
# Out:
# ['Bola', 'Pembatas']

# %%
# Get the names of the output layers
layer_names = net.getLayerNames()
print(layer_names)
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
print(output_layers)

# Start video capture from webcam
cap = cv2.VideoCapture('/Users/amariofausta/Downloads/VID_20230213_110529 (1).mp4')

while True:
    a = time.time()
    # Read a frame from the video capture
    ret, frame = cap.read()
    
    # Create a blob from the input image
    blob = cv2.dnn.blobFromImage(frame, 1/255.0, (416, 416), swapRB=True, crop=False)
    
    # Pass the blob through the network and get the outputs
    net.setInput(blob)
    outputs = net.forward(output_layers)
    
    # Process the outputs to get the detected objects
    # ...
    
    # Display the output image
    cv2.imshow("Output", frame)
    b = time.time() - a
    print(b)
    
    # Wait for a key press to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# ['conv_0', 'bn_0', 'leaky_1', 'conv_1', 'bn_1', 'leaky_2', 'conv_2', 'bn_2', 'leaky_3', 'conv_3', 'bn_3', 'leaky_4', 'shortcut_4', 'conv_5', 'bn_5', 'leaky_6', 'conv_6', 'bn_6', 'leaky_7', 'conv_7', 'bn_7', 'leaky_8', 'shortcut_8', 'conv_9', 'bn_9', 'leaky_10', 'conv_10', 'bn_10', 'leaky_11', 'shortcut_11', 'conv_12', 'bn_12', 'leaky_13', 'conv_13', 'bn_13', 'leaky_14', 'conv_14', 'bn_14', 'leaky_15', 'shortcut_15', 'conv_16', 'bn_16', 'leaky_17', 'conv_17', 'bn_17', 'leaky_18', 'shortcut_18', 'conv_19', 'bn_19', 'leaky_20', 'conv_20', 'bn_20', 'leaky_21', 'shortcut_21', 'conv_22', 'bn_22', 'leaky_23', 'conv_23', 'bn_23', 'leaky_24', 'shortcut_24', 'conv_25', 'bn_25', 'leaky_26', 'conv_26', 'bn_26', 'leaky_27', 'shortcut_27', 'conv_28', 'bn_28', 'leaky_29', 'conv_29', 'bn_29', 'leaky_30', 'shortcut_30', 'conv_31', 'bn_31', 'leaky_32', 'conv_32', 'bn_32', 'leaky_33', 'shortcut_33', 'conv_34', 'bn_34', 'leaky_35', 'conv_35', 'bn_35', 'leaky_36', 'shortcut_36', 'conv_37', 'bn_37', 'leak
# ...

# %%
# Start video capture from webcam
cap = cv2.VideoCapture(0)

while True:
    # Read a frame from the video capture
    ret, frame = cap.read()

    
    # Display the output image
    cv2.imshow("Output", frame)
    
    # Wait for a key press to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
