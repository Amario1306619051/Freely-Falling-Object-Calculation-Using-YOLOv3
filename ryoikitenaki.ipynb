# %%
import numpy as np
import matplotlib.pyplot as plt

g = []
t = []
for i in np.arange(0.200, 0.210, 0.00049):
    g.append(0.6/((0.2*i) + (0.5*i*i)))
    t.append(i)

# %%
g
# Out:
# [9.999999999999998,
#  9.967419818779499,
#  9.935011743399139,
#  9.90277448582734,
#  9.870706770637586,
#  9.838807334855467,
#  9.807074927807918,
#  9.77550831097465,
#  9.744106257841736,
#  9.712867553757272,
#  9.681790995789152,
#  9.65087539258485,
#  9.620119564233217,
#  9.589522342128257,
#  9.559082568834825,
#  9.52879909795624,
#  9.498670794003779,
#  9.468696532267995,
#  9.438875198691873,
#  9.40920568974575,
#  9.379686912304003]

# %%
plt.plot(t,g)
plt.show()
