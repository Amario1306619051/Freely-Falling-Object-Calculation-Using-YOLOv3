# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls '/content/drive/MyDrive/Colab Notebooks/YOLOV3'
# Out:
# DataBola.zip

# %%
# !unzip '/content/drive/MyDrive/Colab Notebooks/YOLOV3/DataBola.zip' -d '/content/drive/MyDrive/Colab Notebooks/YOLOV3'
# Out:
# Archive:  /content/drive/MyDrive/Colab Notebooks/YOLOV3/DataBola.zip
#    creating: /content/drive/MyDrive/Colab Notebooks/YOLOV3/drive-download-20230215T141617Z-001/
#   inflating: /content/drive/MyDrive/Colab Notebooks/YOLOV3/__MACOSX/._drive-download-20230215T141617Z-001
#   inflating: /content/drive/MyDrive/Colab Notebooks/YOLOV3/drive-download-20230215T141617Z-001/File 430.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/YOLOV3/drive-download-20230215T141617Z-001/File 356.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/YOLOV3/drive-download-20230215T141617Z-001/File 342.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/YOLOV3/drive-download-20230215T141617Z-001/File 424.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/YOLOV3/drive-download-20230215T141617Z-001/File 418.jpg
#   inflating: /content/drive/MyDrive/Colab Notebooks/YOLOV3/drive-download-20230215T141617Z-001/File 3.jpg
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/Colab Notebooks/YOLOV3/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/Colab Notebooks/YOLOV3/darknet'...
# remote: Enumerating objects: 15502, done.
# remote: Total 15502 (delta 0), reused 0 (delta 0), pack-reused 15502
# Receiving objects: 100% (15502/15502), 14.17 MiB | 10.09 MiB/s, done.
# Resolving deltas: 100% (10403/10403), done.
# Updating files: 100% (2057/2057), done.

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/YOLOV3/darknet'
# Out:
# /content/drive/MyDrive/Colab Notebooks/YOLOV3/darknet

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   946 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#  1147 |             if (iteration_old == 0)
# ...

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/YOLOV3'
# Out:
# /content/drive/MyDrive/Colab Notebooks/YOLOV3

# %%
# !python DataBola/creating-files-data-and-name.py

# %%
# !python DataBola/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train DataBola/labelled_data.data darknet/cfg/yolov3_custom.cfg weights/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000642, iou_loss = 0.000000, total_loss = 0.000642
#  total_bbox = 157791, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.866256), count: 1, class_loss = 0.000009, iou_loss = 0.043920, total_loss = 0.043929
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
#  total_bbox = 157792, rewritten_bbox = 0.000000 %
# ...
