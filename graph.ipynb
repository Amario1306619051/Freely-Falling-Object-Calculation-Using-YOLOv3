# %%
X = [
    0.933510638,
    0.938172043,
    0.925531915,
    0.927419355,
    0.897849462,
    0.846994536,
    0.842105263,
    0.811634349,
    0.773743017,
    0.644444444,
    0.5,
    0.369047619,
    0.341853035,
    0.389090909,
    0.146031746,
    0.090909091,
    0.056962025,
    0.029069767,
    0
]

Y = [
    0.862407862,
    0.89258312,
    0.913385827,
    0.924932976,
    0.94084507,
    0.953846154,
    0.958990536,
    0.9669967,
    0.965156794,
    0.978902954,
    0.978021978,
    0.992,
    1,
    1,
    1,
    1,
    1,
    1,
    1
]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(X,Y)
plt.ylabel('Precision', fontsize = 23)
plt.xlabel('Recall', fontsize = 23)
# Out:
# Text(0.5, 0, 'Recall')

# %%
import numpy as np
# Menghitung luas dengan metode trapesium
integral = np.trapz(Y, X)

print("Nilai integral:", integral)
# Out:
# Nilai integral: -0.9169205771708503

# %%
# !pip install scipy
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
