# %%
import cv2 
import numpy as np
net = cv2.dnn.readNet('/Users/amariofausta/Documents/Kuliah/Semester 8/Bobot/yolov3-tiny_final.weights','/Users/amariofausta/Documents/Kuliah/Semester 8/Bobot/yolov3-tiny.cfg')
classes = []
with open("/Users/amariofausta/Documents/Kuliah/Semester 8/Code/Dataset/Dataset Custom/classes.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]

# %%
import cv2 
import numpy as np
net = cv2.dnn.readNet('/Users/amariofausta/Documents/Kuliah/Semester 8/Bobot/yolov3custom_last.weights','/Users/amariofausta/Documents/Kuliah/Semester 8/Bobot/yolov3custom.cfg')
with open("/Users/amariofausta/Documents/Kuliah/Semester 8/Code/Dataset/Dataset Custom/classes.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]

# %%
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# Start video capture from webcam
cap = cv2.VideoCapture("/Users/amariofausta/Downloads/VID_20230213_110529 (1).mp4")

while True:
    # Read a frame from the video capture
    ret, frame = cap.read()
    
    # Create a blob from the input image
    blob = cv2.dnn.blobFromImage(frame, 1/255.0, (416, 416), swapRB=True, crop=False)
    
    # Pass the blob through the network and get the outputs
    net.setInput(blob)
    outputs = net.forward(output_layers)
    
    # Process the outputs to get the detected objects
    class_ids = []
    confidences = []
    boxes = []
    for output in outputs:
        for detection in output:
            scores = detection[5:]
            class_id = np.argmax(scores)
            confidence = scores[class_id]
            if confidence > 0.5:
                # Object detected
                center_x = int(detection[0] * frame.shape[1])
                center_y = int(detection[1] * frame.shape[0])
                width = int(detection[2] * frame.shape[1])
                height = int(detection[3] * frame.shape[0])
                x = int(center_x - width / 2)
                y = int(center_y - height / 2)
                class_ids.append(class_id)
                confidences.append(float(confidence))
                boxes.append([x, y, width, height])
    
    # Apply non-maximum suppression to remove redundant detections
    indices = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)
    
    # Draw the detected objects on the image
    for i in indices:
        i = i[0]
        box = boxes[i]
        x = box[0]
        y = box[1]
        w = box[2]
        h = box[3]
        cv2.rectangle(frame, (x, y), (x+w, y+h), (0, 255, 0), 2)
        cv2.putText(frame, classes[class_ids[i]], (x, y-5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    
    # Display the output image
    cv2.imshow("Output", frame)
    
    # Wait for a key press to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 1   HIToolbox                           0x00007ff8114ce726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff8114ce2b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff811472908 SetMenuBarObscured + 408
# 4   HIToolbox                           0x00007ff8114724ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 5   HIToolbox                           0x00007ff81146c996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 6   HIToolbox                           0x00007ff811434bd2 _NotifyEventLoopObservers + 153
# 7   HIToolbox                           0x00007ff81146c3e6 AcquireEventFromQueue + 494
# 8   HIToolbox                           0x00007ff81145b3ec ReceiveNextEventCommon + 285
# 9   HIToolbox                           0x00007ff81145b2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 10  AppKit                              0x00007ff80a658f33 _DPSNextEvent + 909
# 11  AppKit                              0x00007ff80a657db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 12  cv2.cpython-39-darwin.so            0x00000001100d046f cvWaitKey + 319
# 13  cv2.cpython-39-darwin.so            0x00000001100c9ba4 _ZN2cv9waitKeyExEi + 148
# 14  cv2.cpython-39-darwin.so            0x00000001100c9c74 _ZN2cv7waitKeyEi + 36
# 15  cv2.cpython-39-darwin.so            0x000000010f3ba756 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 150
# 16  python3.9                           0x0000000100ea3da4 cfunction_call + 52
# 17  python3.9                           0x0000000100e47e86 _PyObject_MakeTpCall + 134
# 18  python3.9                           0x0000000100f75ee7 call_function + 311
# 19  python3.9                           0x0000000100f6ec51 _PyEval_EvalFrameDefault + 27521
# 20  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 21  python3.9                           0x0000000100f60f09 builtin_exec + 377
# 22  python3.9                           0x0000000100ea4755 cfunction_vectorcall_FASTCALL + 85
# 23  python3.9                           0x0000000100f75e5e call_function + 174
# 24  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 25  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 26  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 27  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 28  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 29  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 30  python3.9                           0x0000000100e56967 method_vectorcall_O + 103
# 31  python3.9                           0x0000000100f75e5e call_function + 174
# 32  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 33  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 34  python3.9                           0x0000000100f75e5e call_function + 174
# 35  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 36  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 37  python3.9                           0x0000000100f75e5e call_function + 174
# 38  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 39  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 40  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 41  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 42  python3.9                           0x0000000100e48783 PyVectorcall_Call + 163
# 43  python3.9                           0x0000000100f6d7d6 _PyEval_EvalFrameDefault + 22278
# 44  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 45  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 46  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 47  python3.9                           0x0000000100f75e5e call_function + 174
# 48  python3.9                           0x0000000100f69252 _PyEval_EvalFrameDefault + 4482
# 49  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 50  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 51  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 52  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 53  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 54  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 55  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 56  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 57  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 58  _asyncio.cpython-39-darwin.so       0x000000010a6c497a task_step_impl + 442
# 59  _asyncio.cpython-39-darwin.so       0x000000010a6c472e task_step + 62
# 60  _asyncio.cpython-39-darwin.so       0x000000010a6c45c8 task_wakeup + 104
# 61  _asyncio.cpython-39-darwin.so       0x000000010a6c44bd TaskWakeupMethWrapper_call + 109
# 62  python3.9                           0x0000000100e47e86 _PyObject_MakeTpCall + 134
# 63  python3.9                           0x0000000100f91641 context_run + 81
# 64  python3.9                           0x0000000100ea468c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 65  python3.9                           0x0000000100f6d7d6 _PyEval_EvalFrameDefault + 22278
# 66  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 67  python3.9                           0x0000000100f75e5e call_function + 174
# 68  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 69  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 70  python3.9                           0x0000000100f75e5e call_function + 174
# 71  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 72  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 73  python3.9                           0x0000000100f75e5e call_function + 174
# 74  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 75  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 76  python3.9                           0x0000000100f75e5e call_function + 174
# 77  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 78  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 79  python3.9                           0x0000000100f75e5e call_function + 174
# 80  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 81  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 82  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 83  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 84  python3.9                           0x0000000100f75e5e call_function + 174
# 85  python3.9                           0x0000000100f6ec51 _PyEval_EvalFrameDefault + 27521
# 86  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 87  python3.9                           0x0000000100f60f09 builtin_exec + 377
# 88  python3.9                           0x0000000100ea4755 cfunction_vectorcall_FASTCALL + 85
# 89  python3.9                           0x0000000100f75e5e call_function + 174
# 90  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 91  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 92  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 93  python3.9                           0x0000000100f75e5e call_function + 174
# 94  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 95  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 96  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 97  python3.9                           0x0000000100ffa142 pymain_run_module + 258
# 98  python3.9                           0x0000000100ff9a01 pymain_run_python + 241
# 99  python3.9                           0x0000000100ff98c5 Py_RunMain + 37
# 100 python3.9                           0x0000000100ffaf90 pymain_main + 64
# 101 python3.9                           0x0000000100ddf408 main + 56
# 102 dyld                                0x00000002011ff310 start + 2432
# 1   HIToolbox                           0x00007ff81145b0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff811497638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff80c13374d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff80c131cf3 CGSSnarfAndDispatchDatagrams + 1055
# 5   SkyLight                            0x00007ff80c440676 SLSGetNextEventRecordInternal + 284
# 6   SkyLight                            0x00007ff80c25d3e8 SLEventCreateNextEvent + 9
# 7   HIToolbox                           0x00007ff811468156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 8   HIToolbox                           0x00007ff8114680fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 9   CoreFoundation                      0x00007ff80760119c __CFMachPortPerform + 244
# 10  CoreFoundation                      0x00007ff8075d4408 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 11  CoreFoundation                      0x00007ff8075d4347 __CFRunLoopDoSource1 + 536
# 12  CoreFoundation                      0x00007ff8075d2fc6 __CFRunLoopRun + 2749
# 13  CoreFoundation                      0x00007ff8075d1e8f CFRunLoopRunSpecific + 560
# 14  HIToolbox                           0x00007ff81145b766 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00007ff81145b396 ReceiveNextEventCommon + 199
# 16  HIToolbox                           0x00007ff81145b2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 17  AppKit                              0x00007ff80a658f33 _DPSNextEvent + 909
# 18  AppKit                              0x00007ff80a657db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 19  cv2.cpython-39-darwin.so            0x00000001100d046f cvWaitKey + 319
# 20  cv2.cpython-39-darwin.so            0x00000001100c9ba4 _ZN2cv9waitKeyExEi + 148
# 21  cv2.cpython-39-darwin.so            0x00000001100c9c74 _ZN2cv7waitKeyEi + 36
# 22  cv2.cpython-39-darwin.so            0x000000010f3ba756 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 150
# 23  python3.9                           0x0000000100ea3da4 cfunction_call + 52
# 24  python3.9                           0x0000000100e47e86 _PyObject_MakeTpCall + 134
# 25  python3.9                           0x0000000100f75ee7 call_function + 311
# 26  python3.9                           0x0000000100f6ec51 _PyEval_EvalFrameDefault + 27521
# 27  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 28  python3.9                           0x0000000100f60f09 builtin_exec + 377
# 29  python3.9                           0x0000000100ea4755 cfunction_vectorcall_FASTCALL + 85
# 30  python3.9                           0x0000000100f75e5e call_function + 174
# 31  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 32  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 33  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 34  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 35  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 36  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 37  python3.9                           0x0000000100e56967 method_vectorcall_O + 103
# 38  python3.9                           0x0000000100f75e5e call_function + 174
# 39  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 40  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 41  python3.9                           0x0000000100f75e5e call_function + 174
# 42  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 43  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 44  python3.9                           0x0000000100f75e5e call_function + 174
# 45  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 46  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 47  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 48  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 49  python3.9                           0x0000000100e48783 PyVectorcall_Call + 163
# 50  python3.9                           0x0000000100f6d7d6 _PyEval_EvalFrameDefault + 22278
# 51  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 52  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 53  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 54  python3.9                           0x0000000100f75e5e call_function + 174
# 55  python3.9                           0x0000000100f69252 _PyEval_EvalFrameDefault + 4482
# 56  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 57  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 58  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 59  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 60  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 61  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 62  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 63  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 64  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 65  _asyncio.cpython-39-darwin.so       0x000000010a6c497a task_step_impl + 442
# 66  _asyncio.cpython-39-darwin.so       0x000000010a6c472e task_step + 62
# 67  _asyncio.cpython-39-darwin.so       0x000000010a6c45c8 task_wakeup + 104
# 68  _asyncio.cpython-39-darwin.so       0x000000010a6c44bd TaskWakeupMethWrapper_call + 109
# 69  python3.9                           0x0000000100e47e86 _PyObject_MakeTpCall + 134
# 70  python3.9                           0x0000000100f91641 context_run + 81
# 71  python3.9                           0x0000000100ea468c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 72  python3.9                           0x0000000100f6d7d6 _PyEval_EvalFrameDefault + 22278
# 73  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 74  python3.9                           0x0000000100f75e5e call_function + 174
# 75  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 76  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 77  python3.9                           0x0000000100f75e5e call_function + 174
# 78  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 79  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 80  python3.9                           0x0000000100f75e5e call_function + 174
# 81  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 82  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 83  python3.9                           0x0000000100f75e5e call_function + 174
# 84  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 85  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 86  python3.9                           0x0000000100f75e5e call_function + 174
# 87  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 88  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 89  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 90  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 91  python3.9                           0x0000000100f75e5e call_function + 174
# 92  python3.9                           0x0000000100f6ec51 _PyEval_EvalFrameDefault + 27521
# 93  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 94  python3.9                           0x0000000100f60f09 builtin_exec + 377
# 95  python3.9                           0x0000000100ea4755 cfunction_vectorcall_FASTCALL + 85
# 96  python3.9                           0x0000000100f75e5e call_function + 174
# 97  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 98  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 99  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 100 python3.9                           0x0000000100f75e5e call_function + 174
# 101 python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 102 python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 103 python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 104 python3.9                           0x0000000100ffa142 pymain_run_module + 258
# 105 python3.9                           0x0000000100ff9a01 pymain_run_python + 241
# 106 python3.9                           0x0000000100ff98c5 Py_RunMain + 37
# 107 python3.9                           0x0000000100ffaf90 pymain_main + 64
# 108 python3.9                           0x0000000100ddf408 main + 56
# 109 dyld                                0x00000002011ff310 start + 2432
# 1   HIToolbox                           0x00007ff8114ce726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff811497638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff80c13374d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff80c131cf3 CGSSnarfAndDispatchDatagrams + 1055
# 5   SkyLight                            0x00007ff80c440676 SLSGetNextEventRecordInternal + 284
# 6   SkyLight                            0x00007ff80c25d3e8 SLEventCreateNextEvent + 9
# 7   HIToolbox                           0x00007ff811468156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 8   HIToolbox                           0x00007ff8114680fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 9   CoreFoundation                      0x00007ff80760119c __CFMachPortPerform + 244
# 10  CoreFoundation                      0x00007ff8075d4408 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 11  CoreFoundation                      0x00007ff8075d4347 __CFRunLoopDoSource1 + 536
# 12  CoreFoundation                      0x00007ff8075d2fc6 __CFRunLoopRun + 2749
# 13  CoreFoundation                      0x00007ff8075d1e8f CFRunLoopRunSpecific + 560
# 14  HIToolbox                           0x00007ff81145b766 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00007ff81145b396 ReceiveNextEventCommon + 199
# 16  HIToolbox                           0x00007ff81145b2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 17  AppKit                              0x00007ff80a658f33 _DPSNextEvent + 909
# 18  AppKit                              0x00007ff80a657db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 19  cv2.cpython-39-darwin.so            0x00000001100d046f cvWaitKey + 319
# 20  cv2.cpython-39-darwin.so            0x00000001100c9ba4 _ZN2cv9waitKeyExEi + 148
# 21  cv2.cpython-39-darwin.so            0x00000001100c9c74 _ZN2cv7waitKeyEi + 36
# 22  cv2.cpython-39-darwin.so            0x000000010f3ba756 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 150
# 23  python3.9                           0x0000000100ea3da4 cfunction_call + 52
# 24  python3.9                           0x0000000100e47e86 _PyObject_MakeTpCall + 134
# 25  python3.9                           0x0000000100f75ee7 call_function + 311
# 26  python3.9                           0x0000000100f6ec51 _PyEval_EvalFrameDefault + 27521
# 27  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 28  python3.9                           0x0000000100f60f09 builtin_exec + 377
# 29  python3.9                           0x0000000100ea4755 cfunction_vectorcall_FASTCALL + 85
# 30  python3.9                           0x0000000100f75e5e call_function + 174
# 31  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 32  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 33  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 34  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 35  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 36  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 37  python3.9                           0x0000000100e56967 method_vectorcall_O + 103
# 38  python3.9                           0x0000000100f75e5e call_function + 174
# 39  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 40  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 41  python3.9                           0x0000000100f75e5e call_function + 174
# 42  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 43  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 44  python3.9                           0x0000000100f75e5e call_function + 174
# 45  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 46  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 47  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 48  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 49  python3.9                           0x0000000100e48783 PyVectorcall_Call + 163
# 50  python3.9                           0x0000000100f6d7d6 _PyEval_EvalFrameDefault + 22278
# 51  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 52  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 53  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 54  python3.9                           0x0000000100f75e5e call_function + 174
# 55  python3.9                           0x0000000100f69252 _PyEval_EvalFrameDefault + 4482
# 56  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 57  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 58  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 59  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 60  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 61  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 62  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 63  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 64  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 65  _asyncio.cpython-39-darwin.so       0x000000010a6c497a task_step_impl + 442
# 66  _asyncio.cpython-39-darwin.so       0x000000010a6c472e task_step + 62
# 67  _asyncio.cpython-39-darwin.so       0x000000010a6c45c8 task_wakeup + 104
# 68  _asyncio.cpython-39-darwin.so       0x000000010a6c44bd TaskWakeupMethWrapper_call + 109
# 69  python3.9                           0x0000000100e47e86 _PyObject_MakeTpCall + 134
# 70  python3.9                           0x0000000100f91641 context_run + 81
# 71  python3.9                           0x0000000100ea468c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 72  python3.9                           0x0000000100f6d7d6 _PyEval_EvalFrameDefault + 22278
# 73  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 74  python3.9                           0x0000000100f75e5e call_function + 174
# 75  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 76  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 77  python3.9                           0x0000000100f75e5e call_function + 174
# 78  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 79  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 80  python3.9                           0x0000000100f75e5e call_function + 174
# 81  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 82  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 83  python3.9                           0x0000000100f75e5e call_function + 174
# 84  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 85  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 86  python3.9                           0x0000000100f75e5e call_function + 174
# 87  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 88  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 89  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 90  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 91  python3.9                           0x0000000100f75e5e call_function + 174
# 92  python3.9                           0x0000000100f6ec51 _PyEval_EvalFrameDefault + 27521
# 93  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 94  python3.9                           0x0000000100f60f09 builtin_exec + 377
# 95  python3.9                           0x0000000100ea4755 cfunction_vectorcall_FASTCALL + 85
# 96  python3.9                           0x0000000100f75e5e call_function + 174
# 97  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 98  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 99  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 100 python3.9                           0x0000000100f75e5e call_function + 174
# 101 python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 102 python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 103 python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 104 python3.9                           0x0000000100ffa142 pymain_run_module + 258
# 105 python3.9                           0x0000000100ff9a01 pymain_run_python + 241
# 106 python3.9                           0x0000000100ff98c5 Py_RunMain + 37
# 107 python3.9                           0x0000000100ffaf90 pymain_main + 64
# 108 python3.9                           0x0000000100ddf408 main + 56
# 109 dyld                                0x00000002011ff310 start + 2432
# 1   HIToolbox                           0x00007ff81145b0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff8114727e3 SetMenuBarObscured + 115
# 3   HIToolbox                           0x00007ff81147929e _ZN13HIApplication11FrontUILostEv + 34
# 4   HIToolbox                           0x00007ff811472622 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 508
# 5   HIToolbox                           0x00007ff81146c950 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 182
# 6   HIToolbox                           0x00007ff811434bd2 _NotifyEventLoopObservers + 153
# 7   HIToolbox                           0x00007ff81146c3e6 AcquireEventFromQueue + 494
# 8   HIToolbox                           0x00007ff81145b3ec ReceiveNextEventCommon + 285
# 9   HIToolbox                           0x00007ff81145b2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 10  AppKit                              0x00007ff80a658f33 _DPSNextEvent + 909
# 11  AppKit                              0x00007ff80a657db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 12  cv2.cpython-39-darwin.so            0x00000001100d046f cvWaitKey + 319
# 13  cv2.cpython-39-darwin.so            0x00000001100c9ba4 _ZN2cv9waitKeyExEi + 148
# 14  cv2.cpython-39-darwin.so            0x00000001100c9c74 _ZN2cv7waitKeyEi + 36
# 15  cv2.cpython-39-darwin.so            0x000000010f3ba756 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 150
# 16  python3.9                           0x0000000100ea3da4 cfunction_call + 52
# 17  python3.9                           0x0000000100e47e86 _PyObject_MakeTpCall + 134
# 18  python3.9                           0x0000000100f75ee7 call_function + 311
# 19  python3.9                           0x0000000100f6ec51 _PyEval_EvalFrameDefault + 27521
# 20  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 21  python3.9                           0x0000000100f60f09 builtin_exec + 377
# 22  python3.9                           0x0000000100ea4755 cfunction_vectorcall_FASTCALL + 85
# 23  python3.9                           0x0000000100f75e5e call_function + 174
# 24  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 25  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 26  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 27  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 28  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 29  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 30  python3.9                           0x0000000100e56967 method_vectorcall_O + 103
# 31  python3.9                           0x0000000100f75e5e call_function + 174
# 32  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 33  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 34  python3.9                           0x0000000100f75e5e call_function + 174
# 35  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 36  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 37  python3.9                           0x0000000100f75e5e call_function + 174
# 38  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 39  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 40  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 41  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 42  python3.9                           0x0000000100e48783 PyVectorcall_Call + 163
# 43  python3.9                           0x0000000100f6d7d6 _PyEval_EvalFrameDefault + 22278
# 44  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 45  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 46  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 47  python3.9                           0x0000000100f75e5e call_function + 174
# 48  python3.9                           0x0000000100f69252 _PyEval_EvalFrameDefault + 4482
# 49  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 50  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 51  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 52  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 53  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 54  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 55  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 56  python3.9                           0x0000000100f70013 _PyEval_EvalFrameDefault + 32579
# 57  python3.9                           0x0000000100e61ccf gen_send_ex + 175
# 58  _asyncio.cpython-39-darwin.so       0x000000010a6c497a task_step_impl + 442
# 59  _asyncio.cpython-39-darwin.so       0x000000010a6c472e task_step + 62
# 60  _asyncio.cpython-39-darwin.so       0x000000010a6c45c8 task_wakeup + 104
# 61  _asyncio.cpython-39-darwin.so       0x000000010a6c44bd TaskWakeupMethWrapper_call + 109
# 62  python3.9                           0x0000000100e47e86 _PyObject_MakeTpCall + 134
# 63  python3.9                           0x0000000100f91641 context_run + 81
# 64  python3.9                           0x0000000100ea468c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 65  python3.9                           0x0000000100f6d7d6 _PyEval_EvalFrameDefault + 22278
# 66  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 67  python3.9                           0x0000000100f75e5e call_function + 174
# 68  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 69  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 70  python3.9                           0x0000000100f75e5e call_function + 174
# 71  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 72  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 73  python3.9                           0x0000000100f75e5e call_function + 174
# 74  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 75  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 76  python3.9                           0x0000000100f75e5e call_function + 174
# 77  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 78  python3.9                           0x0000000100e48bcb function_code_fastcall + 139
# 79  python3.9                           0x0000000100f75e5e call_function + 174
# 80  python3.9                           0x0000000100f6d8fa _PyEval_EvalFrameDefault + 22570
# 81  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 82  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 83  python3.9                           0x0000000100e4be2e method_vectorcall + 158
# 84  python3.9                           0x0000000100f75e5e call_function + 174
# 85  python3.9                           0x0000000100f6ec51 _PyEval_EvalFrameDefault + 27521
# 86  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 87  python3.9                           0x0000000100f60f09 builtin_exec + 377
# 88  python3.9                           0x0000000100ea4755 cfunction_vectorcall_FASTCALL + 85
# 89  python3.9                           0x0000000100f75e5e call_function + 174
# 90  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 91  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 92  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 93  python3.9                           0x0000000100f75e5e call_function + 174
# 94  python3.9                           0x0000000100f6df3d _PyEval_EvalFrameDefault + 24173
# 95  python3.9                           0x0000000100f66a09 _PyEval_EvalCode + 489
# 96  python3.9                           0x0000000100e48b0c _PyFunction_Vectorcall + 236
# 97  python3.9                           0x0000000100ffa142 pymain_run_module + 258
# 98  python3.9                           0x0000000100ff9a01 pymain_run_python + 241
# 99  python3.9                           0x0000000100ff98c5 Py_RunMain + 37
# 100 python3.9                           0x0000000100ffaf90 pymain_main + 64
# 101 python3.9                           0x0000000100ddf408 main + 56
# 102 dyld                                0x00000002011ff310 start + 2432
