# %%
import cv2
import numpy as np

# %%
net = cv2.dnn.readNet('/Users/amariofausta/Downloads/yolov3custom_last.weights','/Users/amariofausta/Downloads/yolov3custom (1).cfg')
classes = []
with open("/Users/amariofausta/Documents/Kuliah/Semester 8/Code/Dataset/Dataset Custom/classes.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]

# %%
classes
# Out:
# ['Bola', 'Pembatas']

# %%
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]

# %%
img = cv2.imread("/Users/amariofausta/Downloads/WhatsApp Image 2023-02-22 at 10.54.41 AM.jpeg")
height, width, channels = img.shape
blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)

# %%
net.setInput(blob)
outs = net.forward(output_layers)

class_ids = []
confidences = []
boxes = []
for out in outs:
    for detection in out:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]
        if confidence > 0.5:
            center_x = int(detection[0] * width)
            center_y = int(detection[1] * height)
            w = int(detection[2] * width)
            h = int(detection[3] * height)
            x = center_x - w / 2
            y = center_y - h / 2
            boxes.append([x, y, w, h])
            confidences.append(float(confidence))
            class_ids.append(class_id)

indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)

font = cv2.FONT_HERSHEY_PLAIN
colors = np.random.uniform(0, 255, size=(len(classes), 3))

for i in range(len(boxes)):
    print(i,indexes)
    if i in indexes:
        x, y, w, h = boxes[i]
        label = str(classes[class_ids[i]])
        color = colors[class_ids[i]]
        cv2.rectangle(img, (int(x), int(y)), (int(x + w), int(y + h)), color, 2)
        cv2.putText(img, label, (int(x), int(y) - 5), font, 1, color, 2)

cv2.imshow("Image", img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 0 [[0]]
# 1   HIToolbox                           0x00007ff8156ae726 _ZN15MenuBarInstance22EnsureAutoShowObserverEv + 102
# 2   HIToolbox                           0x00007ff8156ae2b8 _ZN15MenuBarInstance14EnableAutoShowEv + 52
# 3   HIToolbox                           0x00007ff815652908 SetMenuBarObscured + 408
# 4   HIToolbox                           0x00007ff8156524ca _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 164
# 5   HIToolbox                           0x00007ff81564c996 _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 252
# 6   HIToolbox                           0x00007ff815614bd2 _NotifyEventLoopObservers + 153
# 7   HIToolbox                           0x00007ff81564c3e6 AcquireEventFromQueue + 494
# 8   HIToolbox                           0x00007ff81563b3ec ReceiveNextEventCommon + 285
# 9   HIToolbox                           0x00007ff81563b2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 10  AppKit                              0x00007ff80e838f33 _DPSNextEvent + 909
# 11  AppKit                              0x00007ff80e837db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 12  cv2.cpython-39-darwin.so            0x00000001120e95b2 cvWaitKey + 642
# 13  cv2.cpython-39-darwin.so            0x00000001120e2ba4 _ZN2cv9waitKeyExEi + 148
# 14  cv2.cpython-39-darwin.so            0x00000001120e2c74 _ZN2cv7waitKeyEi + 36
# 15  cv2.cpython-39-darwin.so            0x00000001113d3756 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 150
# 16  python3.9                           0x0000000102ebcda4 cfunction_call + 52
# 17  python3.9                           0x0000000102e60e86 _PyObject_MakeTpCall + 134
# 18  python3.9                           0x0000000102f8eee7 call_function + 311
# 19  python3.9                           0x0000000102f87c51 _PyEval_EvalFrameDefault + 27521
# 20  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 21  python3.9                           0x0000000102f79f09 builtin_exec + 377
# 22  python3.9                           0x0000000102ebd755 cfunction_vectorcall_FASTCALL + 85
# 23  python3.9                           0x0000000102f8ee5e call_function + 174
# 24  python3.9                           0x0000000102f86f3d _PyEval_EvalFrameDefault + 24173
# 25  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 26  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 27  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 28  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 29  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 30  python3.9                           0x0000000102e6f967 method_vectorcall_O + 103
# 31  python3.9                           0x0000000102f8ee5e call_function + 174
# 32  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 33  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 34  python3.9                           0x0000000102f8ee5e call_function + 174
# 35  python3.9                           0x0000000102f86f3d _PyEval_EvalFrameDefault + 24173
# 36  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 37  python3.9                           0x0000000102f8ee5e call_function + 174
# 38  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 39  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 40  python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 41  python3.9                           0x0000000102e64e2e method_vectorcall + 158
# 42  python3.9                           0x0000000102e61783 PyVectorcall_Call + 163
# 43  python3.9                           0x0000000102f867d6 _PyEval_EvalFrameDefault + 22278
# 44  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 45  python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 46  python3.9                           0x0000000102e64e2e method_vectorcall + 158
# 47  python3.9                           0x0000000102f8ee5e call_function + 174
# 48  python3.9                           0x0000000102f82252 _PyEval_EvalFrameDefault + 4482
# 49  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 50  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 51  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 52  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 53  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 54  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 55  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 56  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 57  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 58  _asyncio.cpython-39-darwin.so       0x000000010c6dd97a task_step_impl + 442
# 59  _asyncio.cpython-39-darwin.so       0x000000010c6dd72e task_step + 62
# 60  _asyncio.cpython-39-darwin.so       0x000000010c6dd5c8 task_wakeup + 104
# 61  _asyncio.cpython-39-darwin.so       0x000000010c6dd4bd TaskWakeupMethWrapper_call + 109
# 62  python3.9                           0x0000000102e60e86 _PyObject_MakeTpCall + 134
# 63  python3.9                           0x0000000102faa641 context_run + 81
# 64  python3.9                           0x0000000102ebd68c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 65  python3.9                           0x0000000102f867d6 _PyEval_EvalFrameDefault + 22278
# 66  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 67  python3.9                           0x0000000102f8ee5e call_function + 174
# 68  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 69  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 70  python3.9                           0x0000000102f8ee5e call_function + 174
# 71  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 72  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 73  python3.9                           0x0000000102f8ee5e call_function + 174
# 74  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 75  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 76  python3.9                           0x0000000102f8ee5e call_function + 174
# 77  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 78  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 79  python3.9                           0x0000000102f8ee5e call_function + 174
# 80  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 81  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 82  python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 83  python3.9                           0x0000000102e64e2e method_vectorcall + 158
# 84  python3.9                           0x0000000102f8ee5e call_function + 174
# 85  python3.9                           0x0000000102f87c51 _PyEval_EvalFrameDefault + 27521
# 86  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 87  python3.9                           0x0000000102f79f09 builtin_exec + 377
# 88  python3.9                           0x0000000102ebd755 cfunction_vectorcall_FASTCALL + 85
# 89  python3.9                           0x0000000102f8ee5e call_function + 174
# 90  python3.9                           0x0000000102f86f3d _PyEval_EvalFrameDefault + 24173
# 91  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 92  python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 93  python3.9                           0x0000000102f8ee5e call_function + 174
# 94  python3.9                           0x0000000102f86f3d _PyEval_EvalFrameDefault + 24173
# 95  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 96  python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 97  python3.9                           0x0000000103013142 pymain_run_module + 258
# 98  python3.9                           0x0000000103012a01 pymain_run_python + 241
# 99  python3.9                           0x00000001030128c5 Py_RunMain + 37
# 100 python3.9                           0x0000000103013f90 pymain_main + 64
# 101 python3.9                           0x0000000102df8408 main + 56
# 102 dyld                                0x000000020353c310 start + 2432
# 1   HIToolbox                           0x00007ff81563b0c2 _ZN15MenuBarInstance22RemoveAutoShowObserverEv + 30
# 2   HIToolbox                           0x00007ff815677638 _ZL17BroadcastInternaljPvh + 167
# 3   SkyLight                            0x00007ff81031374d _ZN12_GLOBAL__N_123notify_datagram_handlerEj15CGSDatagramTypePvmS1_ + 1030
# 4   SkyLight                            0x00007ff810311cf3 CGSSnarfAndDispatchDatagrams + 1055
# 5   SkyLight                            0x00007ff810620676 SLSGetNextEventRecordInternal + 284
# 6   SkyLight                            0x00007ff81043d3e8 SLEventCreateNextEvent + 9
# 7   HIToolbox                           0x00007ff815648156 _ZL38PullEventsFromWindowServerOnConnectionjhP17__CFMachPortBoost + 45
# 8   HIToolbox                           0x00007ff8156480fb _ZL14MessageHandlerP12__CFMachPortPvlS1_ + 48
# 9   CoreFoundation                      0x00007ff80b7e119c __CFMachPortPerform + 244
# 10  CoreFoundation                      0x00007ff80b7b4408 __CFRUNLOOP_IS_CALLING_OUT_TO_A_SOURCE1_PERFORM_FUNCTION__ + 41
# 11  CoreFoundation                      0x00007ff80b7b4347 __CFRunLoopDoSource1 + 536
# 12  CoreFoundation                      0x00007ff80b7b2fc6 __CFRunLoopRun + 2749
# 13  CoreFoundation                      0x00007ff80b7b1e8f CFRunLoopRunSpecific + 560
# 14  HIToolbox                           0x00007ff81563b766 RunCurrentEventLoopInMode + 292
# 15  HIToolbox                           0x00007ff81563b396 ReceiveNextEventCommon + 199
# 16  HIToolbox                           0x00007ff81563b2b3 _BlockUntilNextEventMatchingListInModeWithFilter + 70
# 17  AppKit                              0x00007ff80e838f33 _DPSNextEvent + 909
# 18  AppKit                              0x00007ff80e837db4 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 1219
# 19  cv2.cpython-39-darwin.so            0x00000001120e95b2 cvWaitKey + 642
# 20  cv2.cpython-39-darwin.so            0x00000001120e2ba4 _ZN2cv9waitKeyExEi + 148
# 21  cv2.cpython-39-darwin.so            0x00000001120e2c74 _ZN2cv7waitKeyEi + 36
# 22  cv2.cpython-39-darwin.so            0x00000001113d3756 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 150
# 23  python3.9                           0x0000000102ebcda4 cfunction_call + 52
# 24  python3.9                           0x0000000102e60e86 _PyObject_MakeTpCall + 134
# 25  python3.9                           0x0000000102f8eee7 call_function + 311
# 26  python3.9                           0x0000000102f87c51 _PyEval_EvalFrameDefault + 27521
# 27  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 28  python3.9                           0x0000000102f79f09 builtin_exec + 377
# 29  python3.9                           0x0000000102ebd755 cfunction_vectorcall_FASTCALL + 85
# 30  python3.9                           0x0000000102f8ee5e call_function + 174
# 31  python3.9                           0x0000000102f86f3d _PyEval_EvalFrameDefault + 24173
# 32  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 33  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 34  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 35  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 36  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 37  python3.9                           0x0000000102e6f967 method_vectorcall_O + 103
# 38  python3.9                           0x0000000102f8ee5e call_function + 174
# 39  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 40  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 41  python3.9                           0x0000000102f8ee5e call_function + 174
# 42  python3.9                           0x0000000102f86f3d _PyEval_EvalFrameDefault + 24173
# 43  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 44  python3.9                           0x0000000102f8ee5e call_function + 174
# 45  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 46  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 47  python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 48  python3.9                           0x0000000102e64e2e method_vectorcall + 158
# 49  python3.9                           0x0000000102e61783 PyVectorcall_Call + 163
# 50  python3.9                           0x0000000102f867d6 _PyEval_EvalFrameDefault + 22278
# 51  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 52  python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 53  python3.9                           0x0000000102e64e2e method_vectorcall + 158
# 54  python3.9                           0x0000000102f8ee5e call_function + 174
# 55  python3.9                           0x0000000102f82252 _PyEval_EvalFrameDefault + 4482
# 56  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 57  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 58  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 59  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 60  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 61  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 62  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 63  python3.9                           0x0000000102f89013 _PyEval_EvalFrameDefault + 32579
# 64  python3.9                           0x0000000102e7accf gen_send_ex + 175
# 65  _asyncio.cpython-39-darwin.so       0x000000010c6dd97a task_step_impl + 442
# 66  _asyncio.cpython-39-darwin.so       0x000000010c6dd72e task_step + 62
# 67  _asyncio.cpython-39-darwin.so       0x000000010c6dd5c8 task_wakeup + 104
# 68  _asyncio.cpython-39-darwin.so       0x000000010c6dd4bd TaskWakeupMethWrapper_call + 109
# 69  python3.9                           0x0000000102e60e86 _PyObject_MakeTpCall + 134
# 70  python3.9                           0x0000000102faa641 context_run + 81
# 71  python3.9                           0x0000000102ebd68c cfunction_vectorcall_FASTCALL_KEYWORDS + 76
# 72  python3.9                           0x0000000102f867d6 _PyEval_EvalFrameDefault + 22278
# 73  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 74  python3.9                           0x0000000102f8ee5e call_function + 174
# 75  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 76  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 77  python3.9                           0x0000000102f8ee5e call_function + 174
# 78  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 79  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 80  python3.9                           0x0000000102f8ee5e call_function + 174
# 81  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 82  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 83  python3.9                           0x0000000102f8ee5e call_function + 174
# 84  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 85  python3.9                           0x0000000102e61bcb function_code_fastcall + 139
# 86  python3.9                           0x0000000102f8ee5e call_function + 174
# 87  python3.9                           0x0000000102f868fa _PyEval_EvalFrameDefault + 22570
# 88  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 89  python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 90  python3.9                           0x0000000102e64e2e method_vectorcall + 158
# 91  python3.9                           0x0000000102f8ee5e call_function + 174
# 92  python3.9                           0x0000000102f87c51 _PyEval_EvalFrameDefault + 27521
# 93  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 94  python3.9                           0x0000000102f79f09 builtin_exec + 377
# 95  python3.9                           0x0000000102ebd755 cfunction_vectorcall_FASTCALL + 85
# 96  python3.9                           0x0000000102f8ee5e call_function + 174
# 97  python3.9                           0x0000000102f86f3d _PyEval_EvalFrameDefault + 24173
# 98  python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 99  python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 100 python3.9                           0x0000000102f8ee5e call_function + 174
# 101 python3.9                           0x0000000102f86f3d _PyEval_EvalFrameDefault + 24173
# 102 python3.9                           0x0000000102f7fa09 _PyEval_EvalCode + 489
# 103 python3.9                           0x0000000102e61b0c _PyFunction_Vectorcall + 236
# 104 python3.9                           0x0000000103013142 pymain_run_module + 258
# 105 python3.9                           0x0000000103012a01 pymain_run_python + 241
# 106 python3.9                           0x00000001030128c5 Py_RunMain + 37
# 107 python3.9                           0x0000000103013f90 pymain_main + 64
# 108 python3.9                           0x0000000102df8408 main + 56
# 109 dyld                                0x000000020353c310 start + 2432
